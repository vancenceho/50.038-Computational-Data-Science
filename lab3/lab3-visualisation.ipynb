# %% [markdown]
# # Data visualisation in Python
#
# __Prof. Dorien Herremans__
#
#
# **Open the tutorial in 'File -> Playground mode'. Go through the tutorial first. You will find several `#TODO` slots for you to address. They should be easy if you read through in detail. There are a number of open questions for you to solve as well. **
#
#
# For a full overview of types of plots using matplotlib, see the gallery [at https://matplotlib.org/2.0.2/gallery.html](https://matplotlib.org/2.0.2/gallery.html)

# %% [markdown]
# ## Scatterplots
#
# We will be using scottish_hills.csv from [https://github.com/ourcodingclub/CC-python-pandas-matplotlib](https://github.com/ourcodingclub/CC-python-pandas-matplotlib). The file contains all the mountains above 3000 feet (about 914 metres) in Scotland.
#
# We can read this into a variable and see the first 10 lines.
#
# Use the dataframe.head(10) command along with print to have a look into the file.

# %%
import pandas as pd

dataframe = pd.read_csv("https://raw.githubusercontent.com/ourcodingclub/CC-python-pandas-matplotlib/master/scottish_hills.csv")


# TODO print out first 10 lines of the file
print(dataframe.head(10))
# Out:
#                     Hill Name  Height   Latitude  Longitude    Osgrid
# 0       A' Bhuidheanach Bheag   936.0  56.870342  -4.199001  NN660775
# 1               A' Chailleach   997.0  57.693800  -5.128715  NH136714
# 2               A' Chailleach   929.2  57.109564  -4.179285  NH681041
# 3  A' Chraileag (A' Chralaig)  1120.0  57.184186  -5.154837  NH094147
# 4             A' Ghlas-bheinn   918.0  57.255090  -5.303687  NH008231
# 5               A' Mhaighdean   967.0  57.719644  -5.346720  NH007749
# 6              A' Mharconaich   973.2  56.857002  -4.290668  NN604762
# 7                  Am Basteir   934.0  57.247931  -6.202982  NG465253
# 8                   Am Bodach  1031.8  56.741727  -4.983393  NN176650
# 9               Am Faochagach   953.0  57.771801  -4.853899  NH303793

# %% [markdown]
# As explored last week, pandas dataframes can be used for some preliminary data exploration. For instance, let's sort the hills by height:

# %%
sorted_hills = dataframe.sort_values(by=['Height'], ascending=False)

# Let's have a look at the top 5 to check
print(sorted_hills.head(5))
# Out:
#                        Hill Name  Height   Latitude  Longitude    Osgrid
# 92                     Ben Nevis  1344.5  56.796891  -5.003675  NN166712
# 88   Ben Macdui (Beinn Macduibh)  1309.0  57.070368  -3.669099  NN988989
# 104                    Braeriach  1296.0  57.078298  -3.728389  NN953999
# 115                   Cairn Toul  1291.0  57.054397  -3.710773  NN963972
# 212        Sgor an Lochain Uaine  1258.0  57.058369  -3.725797  NN954976

# %% [markdown]
# Now let's load matplotlib. Note: if you are using a jupyter notebook you need the inline statement on line 1 below:

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# To save us some time, let's create some shortcut variables, x and y, to register the hight and latitude coordinates of each of the hills.

# %%
x = dataframe.Height
y = dataframe.Latitude
z = dataframe.Longitude

# %% [markdown]
# Now we are ready to start visualising them. Let's create (and save) a scatterplot. You can use the ` plt.scatter()` command with argument the height and latitude.

# %%
# TODO: create the scatterplot

plt.scatter(x, y)

plt.title("Hills - Height against Latitude")
plt.xlabel("Height (m)")
plt.ylabel("Latitude")

plt.savefig("scottish_scatter_plot.png")

# %% [markdown]
# If you are not using iPython, you can use `plt.show()` to display the plot.
#
# Now let's build upon this graph by adding a linear regression line to it using the `linregress()` command and the same input variables as for scatterplot.

# %%
from scipy.stats import linregress
stats = linregress(x, y)# TODO calculate linear regression

m = stats.slope
b = stats.intercept

print(m, b)
# Out:
# -0.0004276647086117339 57.42672614904847

# %% [markdown]
# Now we can add the plot of our linear regression by using the equation of a straight line.
#
# Add the equation of the linear regression based on the variables and slope/intercept calculated:

# %%
plt.scatter(x, y)

y_new = m * x + b

plt.plot(x, y_new, color="red") #TODO Add equation of the line, color="red")  # The equation of the straight line.

# %% [markdown]
# Note, wether this line is statistically significant can be determined using the extra information in the stats object - `stats.rvalue` and `stats.pvalue`.

# %% [markdown]
# Now you can make your plot look nicer using arguments such as as fontsize, linewidth, color,...

# %%
# Change the default figure size
plt.figure(figsize=(10,10))

# Change the default marker for the scatter from circles to x's
plt.scatter(x, y, marker='x')

# Set the linewidth on the regression line to 3px
plt.plot(x, y_new, linewidth=3, color="red")#TODO add the original arguments + an option for linewidth.

# Add x and y lables, and set their font size
plt.xlabel("Height (m)", fontsize=20)
plt.ylabel("Latitude", fontsize=20)

# Set the font size of the number lables on the axes
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
# Out:
# (array([56. , 56.5, 57. , 57.5, 58. , 58.5, 59. ]),
#  [Text(0, 56.0, '56.0'),
#   Text(0, 56.5, '56.5'),
#   Text(0, 57.0, '57.0'),
#   Text(0, 57.5, '57.5'),
#   Text(0, 58.0, '58.0'),
#   Text(0, 58.5, '58.5'),
#   Text(0, 59.0, '59.0')])

# %% [markdown]
# Let's have a look at how the hills our spread out geographically using latitude (y) and longitude (z). Now we can use s = x to say that the size needs to be equal to the height (x). (I added -900 to make the difference between big and small mountains larger)

# %%
import numpy as np

colors = np.random.rand(len(y))  #generates a different color for each different mountain

plt.scatter(y, z, s = (x-900), c=colors, alpha=0.5)

# %% [markdown]
# ## Histograms

# %% [markdown]
# Let's try some other graphs. A full selection is given at the [matplotlib website](https://matplotlib.org/2.0.2/examples/index.html).
#
# Let's start by looking at the distribution of our hills over the latitude (variable `y` from earlier):

# %%
plt.hist(x, bins=25) #bins separates the latitude in 25 discrete categories.

plt.savefig("histogram.png", dpi=25)  # results in 160x120 px image

# %% [markdown]
# Quickly style your plot with stylesheets, full overview [at https://matplotlib.org/gallery/style_sheets/style_sheets_reference.html](https://matplotlib.org/gallery/style_sheets/style_sheets_reference.html).
#
# Let's also create a new variable that contains the height of the hills -100m. This to illustrate how to add a second distribution to your graph. In this case, we will make them slightly transparent. Density makes sure the graph normalizes the data.
#
# Add a style to the graph using `plt.style.use()`

# %%
import numpy as np

# using a stylesheet:
# TODO add the style 'seaborn-v0_8-deep'
# you can see all available styles like this:
# print(plt.style.available)
plt.style.use('seaborn-v0_8-deep')


#creating the new height variable:
shifted_x = x - 100

fig, ax = plt.subplots() # lets us acces the axis and plot seperately.
ax.hist(x, bins=25, density=True, histtype="stepfilled", alpha=0.8,label='Height')
ax.hist(shifted_x, bins=25, density=True, histtype="stepfilled", alpha=0.8,label='Height - 100')
ax.legend(prop={'size': 10})

ax.set_ylabel('Distribution')
ax.set_xlabel('Height')
# Out:
# Text(0.5, 0, 'Height')

# %% [markdown]
# ## Bar charts
#
# Plot the average $CO_2$ output of both vegetarians and meat eaters for different continents in a bar plot. The data is given below.
#
# Add a legend to the ax using the `legend()` function and set an index value for the rects2 plot.

# %%
labels = ['EU', 'US', 'AS']

meateaters = [122, 135, 80]
vegetarians = [40, 43, 23]


# Keep a numeric index for the x-axis lables. This will be the positions of the ticks.
index = np.arange(len(labels))


fig, ax = plt.subplots()

# Toy with the below parameters to change the appearance of your graph:
bar_width = 0.35
opacity = 0.6

rects1 = ax.bar(index, meateaters, bar_width,
                alpha=opacity, color='b',
                label='Meat eaters')

# Note, shift the x postion also with the bar width so that the bar appears next to the previous one±
rects2 = ax.bar(#TODO set an index which is shifted by the bar_width so that it's not entirely overlapping
                index + bar_width,
                vegetarians, bar_width,
                alpha=opacity, color='r',
                label='Vegetarians')


ax.set_xlabel('Continent')
ax.set_ylabel('CO2 emissions')
ax.set_title('CO2 emissions per continent, per diet')

ax.set_xticks(index + bar_width / 2)

ax.set_xticklabels(labels)

#TODO add legend
ax.legend()

# %% [markdown]
# ## Line plots
#
# Let's move on to another type of graph: a simple line plot, but using two vertical axis.
#
# We will create a function to calculate the temperature in celcius given Fahrenheit. Add the function to calculate Calcius from the Fahrenheit `temp`.

# %%
def fahrenheit2celsius(temp):
    """
    Returns temperature in Celsius.
    """
    return (temp - 32) * 5/9 #TODO return the formula for getting Celcius from Fahrenheit


# TEMPURATURE AT EACH HOUR THROUGHOUT THE DAY (In Fahrenheit)
temperature = [100, 102, 106, 105, 90, 85, 85, 89, 100, 102, 103, 108, 100, 102, 106, 105, 90, 85, 85, 89, 100, 102, 103, 108]

# %% [markdown]
# We will use `twinx` to get a second set of axes. This allows us to plot the temperature evolution throughout the day using both C and F.

# %%
fig, ax_f = plt.subplots()
ax_c = ax_f.twinx()

#plot our data:
ax_f.plot(temperature)
ax_f.set_xlim(0, 24) #x-axis shows 24 hours

# set the axis limits:
y1, y2 = ax_f.get_ylim()
ax_c.set_ylim(fahrenheit2celsius(y1), fahrenheit2celsius(y2))
ax_c.figure.canvas.draw()

# change some axis labels
ax_f.set_title('Two scales: Fahrenheit and Celsius')
ax_f.set_ylabel('Fahrenheit')
ax_c.set_ylabel('Celsius')
ax_f.set_xlabel('Time (hour of day)')
# Out:
# Text(0.5, 23.52222222222222, 'Time (hour of day)')

# %% [markdown]
# Suppose we have a sinusoidal plot (formula line 2 below), and we want to fill it. First let's plot the sinusoid.

# %%
newx = np.linspace(0, 1, 500) # sample 500 X's linearly between 0 and 1
newy = np.sin(4 * np.pi * newx) * np.exp(-5 * newx) #formula for our sinusoidal graph

fig, ax = plt.subplots()  #plt.subplots()  lets us acces the axis and plot seperately.

ax.plot(newx, newy)

# %% [markdown]
# Then we can easily use the `fill()` command of ax to 'fill' the axes with the newly sampled data.

# %%
fig, ax = plt.subplots()

#TODO fill the plot with the newly sampled data newx and newy
ax.fill(newx, newy)

# %% [markdown]
# Axis labels can influence how we perceive the data. Let's have a look at this stock data.

# %%
# growth of stock A
stockA = [0, 10, 20, 30, 40, 60, 80, 140]

plt.plot(stockA)
# plt.ylim(bottom=0, top = 110)
plt.xlabel('Time')
plt.ylabel('Stock A price')
# Out:
# Text(0, 0.5, 'Stock A price')

# %% [markdown]
# Now let's change to a logaritmic axis. Other options here are `linear, log, logit, symlog`. I consolidated the code of the previous plot and put it below. Give it a try.

# %% [markdown]
# ```
# fig = plt.figure()
# ax = fig.add_subplot(1, 1, 1)
#
# line, = ax.plot(stockA)
# ax.set_yscale('log') #change the scale here
#
# plt.xlabel('Time')
# plt.ylabel('Stock A price')
# ax.set_title('Logarithmic')
# ```

# %%
# TODO try different axes scales
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

line, = ax.plot(stockA)
ax.set_yscale('symlog') #change the scale here

plt.xlabel('Time')
plt.ylabel('Stock A price')
# Out:
# Text(0, 0.5, 'Stock A price')

# %% [markdown]
# This illustrates how axes can deform the data...

# %% [markdown]
# ### Boxplots
#
# For all the mountains, let's see what their average height is, with standard deviation in a boxplot.

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x78201dfe82c0>,
#   <matplotlib.lines.Line2D at 0x78201dfe8530>],
#  'caps': [<matplotlib.lines.Line2D at 0x78201dfe8800>,
#   <matplotlib.lines.Line2D at 0x78201dfe8ad0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x78201dfb3fe0>],
#  'medians': [<matplotlib.lines.Line2D at 0x78201dfe8d70>],
#  'fliers': [<matplotlib.lines.Line2D at 0x78201dfe9070>],
#  'means': []}

# %% [markdown]
# Easy enough. Now we can make this slightly nicer:

# %%
# notched plot
plt.figure()
plt.boxplot(x, 1)

# change outlier point symbols
plt.figure()
plt.boxplot(x, 0, 'gD')

# don't show outlier points
plt.figure()
plt.boxplot(x, 0, '')

# horizontal boxes
plt.figure()
plt.boxplot(x, 0, 'rs', 0)

# change whisker length
plt.figure()
plt.boxplot(x, 0, 'rs', 0, whis=0.75)
# Out:
# /tmp/ipython-input-3810079009.py:3: MatplotlibDeprecationWarning: Passing the notch parameter of boxplot() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.boxplot(x, 1)
# /tmp/ipython-input-3810079009.py:7: MatplotlibDeprecationWarning: Passing the notch parameter of boxplot() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.boxplot(x, 0, 'gD')
# /tmp/ipython-input-3810079009.py:11: MatplotlibDeprecationWarning: Passing the notch parameter of boxplot() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.boxplot(x, 0, '')
# /tmp/ipython-input-3810079009.py:15: MatplotlibDeprecationWarning: Passing the notch parameter of boxplot() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.boxplot(x, 0, 'rs', 0)
# /tmp/ipython-input-3810079009.py:19: MatplotlibDeprecationWarning: Passing the notch parameter of boxplot() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.boxplot(x, 0, 'rs', 0, whis=0.75)
# {'whiskers': [<matplotlib.lines.Line2D at 0x78201dedae10>,
#   <matplotlib.lines.Line2D at 0x78201dedb0b0>],
#  'caps': [<matplotlib.lines.Line2D at 0x78201dedb3e0>,
#   <matplotlib.lines.Line2D at 0x78201dedb6b0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x78201dedaae0>],
#  'medians': [<matplotlib.lines.Line2D at 0x78201dedb9b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x78201dedbc50>],
#  'means': []}

# %% [markdown]
# # Now to try yourself - exercises (for checkoff):
#
# Load the dataset from `https://raw.githubusercontent.com/plotly/datasets/master/school_earnings.csv`, and have a look at what it contains.
#
# Then create the following:
#
# 1. A __histogram__ of the salaries for women.
# 2. Add the men's salaries to this histogram.
# 3. Give your histogram a dark background and label the axes.
# 4. Next, please label the colors of the histogram so we know who is what (men vs women).
# 5. Instead of a histogram, create a __bar chart__ that lists the salary for women (y-axis) for each school.
# 6. Also add men to this bar chart.
# 7. Make the style nice and add labels.
# 8. Now create a nice __boxplot__ of the data, one for men, one for women (two box's same graph).

# %% [markdown]
# ### Load Dataset & Visualise

# %%
checkoff_dataframe = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/school_earnings.csv")


# TODO print out first 10 lines of the file
print(checkoff_dataframe.head(10))
# Out:
#        School  Women  Men  Gap
# 0         MIT     94  152   58
# 1    Stanford     96  151   55
# 2     Harvard    112  165   53
# 3      U.Penn     92  141   49
# 4   Princeton     90  137   47
# 5     Chicago     78  118   40
# 6  Georgetown     94  131   37
# 7       Tufts     76  112   36
# 8        Yale     79  114   35
# 9    Columbia     86  119   33

# %%
sorted_women = checkoff_dataframe.sort_values(by=['Women'], ascending=False)
print(sorted_women.head(10))
# Out:
#         School  Women  Men  Gap
# 2      Harvard    112  165   53
# 1     Stanford     96  151   55
# 0          MIT     94  152   58
# 6   Georgetown     94  131   37
# 10        Duke     93  124   31
# 3       U.Penn     92  141   49
# 4    Princeton     90  137   47
# 9     Columbia     86  119   33
# 11   Dartmouth     84  114   30
# 14     Cornell     80  107   27

# %% [markdown]
# ## Solution: histogram

# %% [markdown]
# ### TODO-1: Histogram of Salries for Women

# %%
checkoff_women = checkoff_dataframe.Women

# %%
import numpy as np

plt.style.use('seaborn-v0_8-deep')

plt.title("Salaries for Women")
plt.xlabel("Salary")
plt.ylabel("Frequency")

fig = plt.hist(checkoff_women, bins=5) #bins separates the latitude in 25 discrete categories.

# %% [markdown]
# ### TODO-2: Histogram of Salaries for Women & Men

# %%
# using a stylesheet:
# TODO add the style 'seaborn-v0_8-deep'
# you can see all available styles like this:
# print(plt.style.available)
plt.style.use('seaborn-v0_8-deep')


# men's salaries
checkoff_men = checkoff_dataframe.Men


fig, ax = plt.subplots() # lets us acces the axis and plot seperately.
ax.hist(checkoff_women, bins=5, density=True, histtype="stepfilled", alpha=0.8,label='Women')
ax.hist(checkoff_men, bins=5, density=True, histtype="stepfilled", alpha=0.8,label='Men')
ax.legend(prop={'size': 10})

ax.set_ylabel('Frequency')
ax.set_xlabel('Salary')

plt.title("Historgram of Salaries")
# Out:
# Text(0.5, 1.0, 'Historgram of Salaries')

# %% [markdown]
# ### TODO-3&4: Changing to a dark background + label the axes + label the colors of gender

# %%
# using a stylesheet:
# TODO add the style 'seaborn-v0_8-deep'
# you can see all available styles like this:
# print(plt.style.available)
plt.style.use('dark_background')


# men's salaries
checkoff_men = checkoff_dataframe.Men


fig, ax = plt.subplots() # lets us acces the axis and plot seperately.
ax.hist(checkoff_women, bins=5, density=True, histtype="stepfilled", alpha=0.8,label='Women')
ax.hist(checkoff_men, bins=5, density=True, histtype="stepfilled", alpha=0.8,label='Men')
ax.legend(prop={'size': 10})

ax.set_ylabel('Frequency')
ax.set_xlabel('Salary')

plt.title("Historgram of Salaries")
# Out:
# Text(0.5, 1.0, 'Historgram of Salaries')

# %% [markdown]
# ## Solution: Bar chart

# %% [markdown]
# ### TODO-5: Bar Chart listing Women Salaries for Each School

# %%
labels = checkoff_dataframe.School

women = checkoff_dataframe.Women
men = checkoff_dataframe.Men

index = np.arange(len(labels))

# %%
plt.style.use('seaborn-v0_8-deep')

plt.figure(figsize=(10, 6))
plt.bar(labels, women, color='skyblue')

plt.xlabel("School")
plt.ylabel("Salary")
plt.title("Women's Salary by School")
plt.xticks(rotation=45, ha="right")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### TODO-6&7: Bar Chart Listing Salaries for Women & Men for Each School + Add labels and colors

# %%
plt.style.use("seaborn-v0_8-deep")

fig, ax = plt.subplots(figsize=(10, 6))

bar_width = 0.35
opacity = 0.6

women_rects = ax.bar(index, women, bar_width,
                alpha=opacity,
                label='Women')

men_rects = ax.bar(index + bar_width, men, bar_width,
                alpha=opacity,
                label='Men')

ax.set_xlabel('School')
ax.set_ylabel('Salary')
ax.set_title('Salary per School')

ax.set_xticks(index + bar_width / 2)

ax.set_xticklabels(labels, rotation=45, ha="right")

ax.legend()

# %% [markdown]
# ## Solution: Boxplot

# %% [markdown]
# ### TODO-8: Boxplot of Salary Distribution for Women & Men

# %%
fig, ax = plt.subplots(figsize=(8, 6))

# Data passed as a list-of-lists: [women, men]
box = ax.boxplot(
    [women, men],
    labels=['Women', 'Men'],
    patch_artist=True  # allows coloring the boxes
)

# Color the boxes
colors = ['skyblue', 'lightcoral']
for patch, color in zip(box['boxes'], colors):
    patch.set_facecolor(color)

ax.set_ylabel('Salary')
ax.set_title('Salary Distribution by Gender')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-2580913385.py:4: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   box = ax.boxplot(

# %% [markdown]
# Well done!

# %% [markdown]
# ## Interactive fun
#
# There are a lot of libraries available to make plots more dynamic, for instance: https://mode.com/blog/python-interactive-plot-libraries/
#
# Let's experiment a bit with Ploly: https://plotly.com/python/

# %%
import plotly.graph_objects as go
import pandas as pd

# Read data from a csv
z_data = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/api_docs/mt_bruno_elevation.csv')

fig = go.Figure(data=go.Surface(z=z_data, showscale=False))
fig.update_layout(
    title='Mt Bruno Elevation',
    width=400, height=400,
    margin=dict(t=40, r=0, l=20, b=20)
)

name = 'default'
# Default parameters which are used when `layout.scene.camera` is not provided
camera = dict(
    up=dict(x=0, y=0, z=1),
    center=dict(x=0, y=0, z=0),
    eye=dict(x=1.25, y=1.25, z=1.25)
)

fig.update_layout(scene_camera=camera, title=name)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="548c1cf0-7593-4a1c-bf1d-4d9a54712e1a" class="plotly-graph-div" style="height:400px; width:400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("548c1cf0-7593-4a1c-bf1d-4d9a54712e1a")) {                    Plotly.newPlot(                        "548c1cf0-7593-4a1c-bf1d-4d9a54712e1a",                        [{"showscale":false,"z":[[0.0,27.80985,49.61936,83.08067,116.6632,130.414,150.7206,220.1871,156.1536,148.6416,203.7845,206.0386,107.1618,68.36975,45.3359,49.96142,21.89279,17.02552,11.74317,14.75226,13.6671,5.677561,3
,0.0,0.0],[13.0,0.0,48.08919,142.5558,140.3777,154.7261,87.9361,58.11092,52.83869,67.14822,83.66798,118.9242,150.0681,272.9709,341.1366,238.664,190.2,116.8943,91.48672,14.0157,42.29277,5.115252,0.0,0.0,0.0],[14.0,0.0,54.1941,146.3839,99.48143,96.19411,102.9473,76.14089,57.7844,47.0402,64.36799,84.23767,162.7181,121.3275,213.1646,328.482,285.4489,283.8319,212.815,164.549,92.29631,7.244015,1.167,0.0,0.0],[15.0,0.0,6.919659,195.1709,132.5253,135.2341,89.85069,89.45549,60.29967,50.33806,39.17583,59.06854,74.52159,84.93402,187.1219,123.9673,103.7027,128.986,165.1283,249.7054,95.39966,10.00284,2.39255,0.0,0.0],[16.0,0.0,21.73871,123.1339,176.7414,158.2698,137 ...

# %% [markdown]
# Move the plot around to see how it's interactive. Check out many more of the solutions on the plotly demo site
#
# ## Exercise (for checkoff):
#
# * Take the scatterplot from the scottish hills before, but now, visualize the height of the point you are hoovering over dynamically. You can use the template from https://plotly.com/python/click-events/
#
# Be sure to end with `f.show()`

# %%
import plotly.graph_objects as go

# Assuming x (Height) and y (Latitude) are already defined from the Scottish hills data
# x = dataframe.Height
# y = dataframe.Latitude

fig = go.Figure(data=go.Scatter(
    x=x,
    y=y,
    mode='markers',
    hoverinfo='text',
    hovertext=[f'Height: {h:.1f}m' for h in x] # Display height on hover
))

fig.update_layout(
    title='Scottish Hills: Height vs Latitude (Hover for Height)',
    xaxis_title='Height (m)',
    yaxis_title='Latitude'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="57cd8ed5-aa06-4b34-a18e-f0e955703c54" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("57cd8ed5-aa06-4b34-a18e-f0e955703c54")) {                    Plotly.newPlot(                        "57cd8ed5-aa06-4b34-a18e-f0e955703c54",                        [{"hoverinfo":"text","hovertext":["Height: 936.0m","Height: 997.0m","Height: 929.2m","Height: 1120.0m","Height: 918.0m","Height: 967.0m","Height: 973.2m","Height: 934.0m","Height: 1031.8m","Height: 953.0m","Height: 995.8m","Height: 923.9m","Height: 981.4m","Height: 1129.0m","Height: 1006.5m","Height: 1069.0m","Height: 944.0m","Height: 921.0m","Height: 1117.1m","Height: 1062.5m","Height: 1058.6m","Height: 1019.5m","Height: 1234.0m","Height: 1115.8m","Height: 952.2m","Height: 967.7m","Height: 1001.0m","Height: 1221.0m","Height: 1024.0m","Height: 1001.0m","Height: 1197.0m","Height: 1083.0m","Height: 1052.0m","Height: 1087.0m","Height: 916.3m","Height: 980.0m","Height: 1080.6m","Height: 941.4m","Height: 1070.0m","Height: 976.0m","Height: 1121.9m","Height: 1038.5m","Height: 986.0m","Height: 922.0m","Height: 1004.0m","Height: 1019.0m","Height: 931.0m","Height: 1157.0m","Height: 948.5m","Height: 932.1m","Height: 1084.0m","Height: 1008.7m","Height: 1076.0m","Height: 978.0m","Height: 1103.2m","Height: 1010.0m","Height: 993.0m","Height: 989.0m","Height: 1032.0m","Height: 1004.7m","Height: 959.0m","Height: 1103.0
inois",37240],["Montana",69122],["California",99769],["Texas",100065],["Arizona",229972],["Wisconsin",39309],["North Carolina",431746],["California",139969],["California",66900],["Washington",39056],["California",55174],["Arizona",38290],["Florida",186411],["Texas",63032],["Virginia",43609],["Texas",1409019],["Connecticut",125017],["Iowa",68366],["New York",46444],["Idaho",83596],["Wisconsin",42970],["Texas",75418],["North Carolina",151088],["Massachusetts",55419],["Oklahoma",398121],["Texas",81050],["Ohio",49267],["Massachusetts",60509],["Texas",92020],["Arizona",526116],["Tennessee",68886],["Minnesota",39167],["Florida",842583],["New Jersey",39551],["Pennsylvania ...

# %% [markdown]
# ### Exercise (for checkoff):
#
# Now use the same technique to display the Scottish Hills yet again with a hooverable height over the map.

# %%
import plotly.express as px

fig = px.scatter_mapbox(dataframe,
                        lat="Latitude",
                        lon="Longitude",
                        hover_name="Hill Name",
                        hover_data={'Height':True},
                        color_discrete_sequence=["blue"],
                        zoom=5,
                        height=600)

fig.update_layout(mapbox_style="open-street-map")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1b139982-64fc-43b9-b1d5-a43dc5e9d507" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1b139982-64fc-43b9-b1d5-a43dc5e9d507")) {                    Plotly.newPlot(                        "1b139982-64fc-43b9-b1d5-a43dc5e9d507",                        [{"customdata":[[936.0],[997.0],[929.2],[1120.0],[918.0],[967.0],[973.2],[934.0],[1031.8],[953.0],[995.8],[923.9],[981.4],[1129.0],[1006.5],[1069.0],[944.0],[921.0],[1117.1],[1062.5],[1058.6],[1019.5],[1234.0],[1115.8],[952.2],[967.7],[1001.0],[1221.0],[1024.0],[1001.0],[1197.0],[1083.0],[1052.0],[1087.0],[916.3],[980.0],[1080.6],[941.4],[1070.0],[976.0],[1121.9],[1038.5],[986.0],[922.0],[1004.0],[1019.0],[931.0],[1157.0],[948.5],[932.1],[1084.0],[1008.7],[1076.0],[978.0],[1103.2],[1010.0],[993.0],[989.0],[1032.0],[1004.7],[959.0],[1103.0],[1011.0],[1045.0],[926.0],[954.0],[953.0],[1182.9],[935.0],[960.0],[927.0],[974.0],[937.0],[1077.4],[937.0],[914.6],[945.8],[1010.2],[1148.0],[1171.0],[1025.0],[931.0],[1127.0],[927.0],[962.1],[1214.0],[974.0],[1130.0],[1309.0],[1174.0],[966.0],[998.0],[1344.5],[1029.0],[1078.0],[915.8],[985.0],[943.0],[1046.0],[1149.4],[945.0],[943.0],[1130.0],[929.0],[1296.0],[998.0],[958.0],[925.0],[958.0],[1021.4],[953.4],[1090.0],[1012.0],[1244.8],[1064.0],[1291.0],[963.5],[1109.9],[975.0],[1037.0],[994.1],[1029.0],[1047.0],[1019.0],[915.3],[945.1],[1034.0],[945.7],[941.0],[1182.8],[957.0],[1029.0],[1006.0],[1042.0],[1220.0],[940.8],[993.0],[992.0],[920.3],[1046.0],[979.0],[978.0],[987.0],[946.0],[988.2],[1128.0],[1047.0],[918.0],[924.0],[1099.8],[1045.9],[1155.0],[947.0],[987.0],[927.0],[933.0],[919.0],[1013.0],[1049.0],[926.0],[1132.0],[917.1],[997.0],[1068.0],[1051.0],[1035.0],[987.0],[1020.0],[1023.0],[1055.0],[1156.0],[939.0],[987.0],[1179.4],[1004.9],[933.0],[980.3],[928.0],[1107.9],[925.6],[934.0],[946.0],[932.1],[951.0],[1069.0],[1123.1],[968.0],[1039.8],[959.0],[949.0],[1001.0],[981.0],[918.0],[977.0],[928.0],[1043.5],[1113.0],[928.0],[939.0],[1019.0],[1015.2],[1102.0],[982.0],[939.3],[1054.2],[918.7],[1002.0],[956.0],[1083.0],[926.0],[991.0],[920.0],[1258.0],[955.0],[1118.0],[960.7],[1036.0],[1053.0],[1083.0],[973.0],[918.0],[1099.0],[1027.0],[992.0],[1010.0],[1004.0],[989.0],[999.0],[999.2],[1094.0],[986.0],[944.0],[1010.0],[1049.0],[1068.7],[948.0],[1108.0],[1003.0],[965.0],[1002.0],[1040.0],[1027.0],[994.0],[1151.0],[993.0],[946.0],[1151.0],[1093.0],[956.0],[953.0],[1109.0],[923.0],[926.2],[964.0],[963.0],[981.0],[996.0],[937.0],[1105.0],[945.0],[999.7],[977.0],[1165.0],[1177.0],[1044.0],[981.4],[1116.0],[1115.0],[1072.0],[979.0],[999.2],[1090.0],[1054.0],[975.0],[960.0],[933.0],[1004.0],[1011.4],[1054.0],[958.0],[1112.0],[957.0]],"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eLatitude=%{lat}\u003cbr\u003eLongitude=%{lon}\u003cbr\u003eHeight=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["A' Bhuidheanach Bheag","A' Chailleach","A' Chailleach","A' Chraileag (A' Chralaig)","A' Ghlas-bheinn","A' Mhaighdean","A' Mharconaich","Am Basteir","Am Bodach","Am Faochagach","An Caisteal","An Coileachan","An Gearanach","An Riabhachan","An Sgarsoch","An Socach","An Socach","An Socach","An Stuc","An Teallach-Bidein a' Ghlas Thuill","An Teallach-Sgurr Fiona","Aonach air Chrith","Aonach Beag","Aonach Beag","Aonach Eagach-Meall Dearg","Aonach Eagach-Sgorr nam Fiannaidh","Aonach Meadhoin","Aonach Mor","Beinn a' Bheithir-Sgorr Dhearg","Beinn a' Bheithir-Sgorr Dhonuill","Beinn a' Bhuird (Beinn a' Bhuird North Top)","Beinn a' Chaorainn","Beinn a' Chaorainn","Beinn a' Chlachair","Beinn a' Chleibh","Beinn a' Chochuill","Beinn a' Chreachain","Beinn a' Chroin","Beinn a' Ghlo-Braigh Coire Chruinn-bhal ...

# %% [markdown]
# ## Extra video - tableau:
#
# A great tool for data visualisation (and management) is Tableau. We won't be seeing this is detail as this is not a big data or database course, but for those of you interested here is a very quick intro:
#
# https://youtu.be/7Jl-RwkzqQ4?t=327

# %%
# play video in Colab:
from IPython.display import HTML

HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/7Jl-RwkzqQ4?t=327" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')
# Out:
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py:724: UserWarning:
#
# Consider using IPython.display.IFrame instead
# <iframe width="560" height="315" src="https://www.youtube.com/embed/7Jl-RwkzqQ4?t=327" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# You can take it one step further and watch this demo on how to make a covid dashboard with Tableau: https://www.youtube.com/watch?v=mvpGTXRLIQc

# %%
HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/v=mvpGTXRLIQc" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/v=mvpGTXRLIQc" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
